# %% [markdown]
# # plant leaf disesase predection

# %% [markdown]
# # importing dataset

# %% [markdown]
# Dataset Link : https://www.kaggle.com/datasets/vipoooool/new-plant-diseases-dataset/data

# %%
pip install tensorflow
# Out:
# ...
#    ---------------------------------------- 0.0/26.4 MB ? eta -:--:--
#    ---------------------------------------- 0.1/26.4 MB 1.7 MB/s eta 0:00:16
#    ---------------------------------------- 0.1/26.4 MB 1.7 MB/s eta 0:00:16
#    ---------------------------------------- 0.2/26.4 MB 1.6 MB/s eta 0:00:17
#    ---------------------------------------- 0.3/26.4 MB 1.6 MB/s eta 0:00:17
#     --------------------------------------- 0.3/26.4 MB 1.5 MB/s eta 0:00:17
#     --------------------------------------- 0.4/26.4 MB 1.5 MB/s eta 0:00:18
#     --------------------------------------- 0.5/26.4 MB 1.5 MB/s eta 0:00:17
#     --------------------------------------- 0.6/26.4 MB 1.5 MB/s eta 0:00:18
#     --------------------------------------- 0.6/26.4 MB 1.5 MB/s eta 0:00:18
#    - -------------------------------------- 0.7/26.4 MB 1.5 MB/s eta 0:00:17
#    - -------------------------------------- 0.8/26.4 MB 1.5 MB/s eta 0:00:17
# ...

# %% [markdown]
# # importing libraries

# %% [markdown]
# import tensorflow as tf
# import pandas as pd
# import numpy as np
# import seaborn as sns
# import matplotlib.pyplot as plt

# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    ---------------------------------------- 0.1/11.6 MB 939.4 kB/s eta 0:00:13
#    ---------------------------------------- 0.1/11.6 MB 939.4 kB/s eta 0:00:13
#     --------------------------------------- 0.2/11.6 MB 1.2 MB/s eta 0:00:10
#     --------------------------------------- 0.2/11.6 MB 1.2 MB/s eta 0:00:10
#    - -------------------------------------- 0.4/11.6 MB 1.1 MB/s eta 0:00:11
#    - -------------------------------------- 0.5/11.6 MB 1.2 MB/s eta 0:00:10
#    - -------------------------------------- 0.5/11.6 MB 1.2 MB/s eta 0:00:10
#    -- ------------------------------------- 0.6/11.6 MB 1.2 MB/s eta 0:00:09
#    -- ------------------------------------- 0.6/11.6 MB 1.3 MB/s eta 0:00:09
# ...

# %%
pip install seaborn
# Out:
# ...
#      ---------------------------------------- 0.0/162.8 kB ? eta -:--:--
#      -------------- ------------------------ 61.4/162.8 kB 3.4 MB/s eta 0:00:01
#      ------------------------------- ------ 133.1/162.8 kB 1.6 MB/s eta 0:00:01
#      -------------------------------------- 162.8/162.8 kB 1.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    ----- --------------------------------- 41.0/294.9 kB 960.0 kB/s eta 0:00:01
#    ---------------- ----------------------- 122.9/294.9 kB 1.4 MB/s eta 0:00:01
#    -------------------------- ------------- 194.6/294.9 kB 1.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 256.0/294.9 kB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 294.9/294.9 kB 1.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/7.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.7 MB 2.0 MB/s eta 0:00:04
# ...

# %% [markdown]
# # Data preprocessing

# %% [markdown]
# # Taining image preprocessing

# %%
training_set = tf.keras.utils.image_dataset_from_directory(
    'train',
    labels="inferred",
    label_mode="int",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(128, 128),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False,
    pad_to_aspect_ratio=False,
    data_format=None,
    verbose=True,
)
# Out:
#   Cell In[2], line 18
#     verbose=True,
#                  ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# ### validation image preprocessing

# %%
training_set = tf.keras.utils.image_dataset_from_directory(
    'valid',
    labels="inferred",
    label_mode="int",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(128, 128),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False,
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 training_set = tf.keras.utils.image_dataset_from_directory(
#       2     'valid',
#       3     labels="inferred",
#       4     label_mode="int",
#       5     class_names=None,
#       6     color_mode="rgb",
#       7     batch_size=32,
#       8     image_size=(128, 128),
#       9     shuffle=True,
#      10     seed=None,
#      11     validation_split=None,
#      12     subset=None,
#      13     interpolation="bilinear",
#      14     follow_links=False,
#      15     crop_to_aspect_ratio=False,
#      16 )
#
# NameError: name 'tf' is not defined

# %%
training_set

# %%
for x,y in training_set:
    print(x,y)
    print(y)
    break

# %% [markdown]
# ## building model

# %%
from tensorflow.keras.layers import Dense,Cov2D
from tensorflow.keras.models import Sequential
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from tensorflow.keras.layers import Dense,Cov2D
#       2 from tensorflow.keras.models import Sequential
#
# ImportError: cannot import name 'Cov2D' from 'tensorflow.keras.layers' (C:\Users\ABHISHEK\anaconda3\envs\tensorflow\lib\site-packages\keras\api\_v2\keras\layers\__init__.py)

# %% [markdown]
# model = sequential()

# %%
## builiding convolutionlayer

# %%
model.add(Con2D(filters=32,kernal_size = 3,padding='same',activation='relu',input_shape=[128,128,3]))
model.add(Con2D(filters=32,kernal_size = 3,padding='same',activation='relu'))
model.add(Maxpool2D(pool_size=2,strides=2))

# %%
model.add(Con2D(filters=64,kernal_size = 3,padding='same',activation='relu',input_shape=[128,128,3]))
model.add(Con2D(filters=64,kernal_size = 3,padding='same',activation='relu'))
model.add(Maxpool2D(pool_size=2,strides=2))

# %%
model.add(Con2D(filters=128,kernal_size = 3,padding='same',activation='relu',input_shape=[128,128,3]))
model.add(Con2D(filters=128,kernal_size = 3,padding='same',activation='relu'))
model.add(Maxpool2D(pool_size=2,strides=2))

# %%
model.add(Con2D(filters=256,kernal_size = 3,padding='same',activation='relu',input_shape=[128,128,3]))
model.add(Con2D(filters=256,kernal_size = 3,padding='same',activation='relu'))
model.add(Maxpool2D(pool_size=2,strides=2))

# %%
model.add(Flatten())

# %%
model.add(Dense(units=1024,activation='relu'))

# %%
#output layer
model.add(Dense(units=38,activation='softmax'))

# %% [markdown]
# ### compiling model

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %% [markdown]
# ## Model Training

# %%
training_history = model.fit(x=training_set,validation_data=validation_set,epochs=10)

# %%
model.summary()
